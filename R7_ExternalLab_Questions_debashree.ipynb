# %% [markdown]
# ### Build a DNN using Keras with `RELU` and `ADAM`

# %% [markdown]
# #### Load tensorflow

# %%
import tensorflow as tf

# %% [markdown]
# #### Collect Fashion mnist data from tf.keras.datasets

# %%
from keras.datasets import fashion_mnist
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()
# Out:
# Using TensorFlow backend.
# Downloading data from http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 3us/step
# Downloading data from http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 2s 0us/step
# Downloading data from http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz
# 8192/5148 [===============================================] - 0s 0us/step
# Downloading data from http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 1s 0us/step

# %% [markdown]
# #### Change train and test labels into one-hot vectors

# %%
Y_train=tf.keras.utils.to_categorical(y_train)
Y_test=tf.keras.utils.to_categorical(y_test)

# %% [markdown]
# #### Build the Graph

# %% [markdown]
# #### Initialize model, reshape & normalize data

# %%
#normalize
X_train=x_train/255
X_test=x_test/255

# %%
#reshape
X_train =X_train.reshape(X_train.shape[0], 28, 28, 1)
X_test =X_test.reshape(X_test.shape[0], 28, 28, 1)

# %% [markdown]
# #### Add two fully connected layers with 200 and 100 neurons respectively with `relu` activations. Add a dropout layer with `p=0.25`

# %%
model = tf.keras.models.Sequential()
#model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.Conv2D(32, kernel_size=(3,3), activation='relu'))
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dropout(0.25))
model.add(tf.keras.layers.Dense(200, activation='relu'))
model.add(tf.keras.layers.Dense(100, activation='relu'))
model.add(tf.keras.layers.Dense(10, activation='softmax'))
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0825 12:35:28.478888 140089305962368 deprecation.py:506] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor

# %% [markdown]
# ### Add the output layer with a fully connected layer with 10 neurons with `softmax` activation. Use `categorical_crossentropy` loss and `adam` optimizer and train the network. And, report the final validation.

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.fit(X_train,Y_train,validation_data=(X_test,Y_test),epochs=10,batch_size=32)
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/10
# 60000/60000 [==============================] - 128s 2ms/sample - loss: 0.3837 - acc: 0.8613 - val_loss: 0.3170 - val_acc: 0.8859
# Epoch 2/10
# 60000/60000 [==============================] - 128s 2ms/sample - loss: 0.2503 - acc: 0.9059 - val_loss: 0.3006 - val_acc: 0.8914
# Epoch 3/10
# 60000/60000 [==============================] - 127s 2ms/sample - loss: 0.2007 - acc: 0.9251 - val_loss: 0.2932 - val_acc: 0.8944
# Epoch 4/10
# 60000/60000 [==============================] - 127s 2ms/sample - loss: 0.1604 - acc: 0.9403 - val_loss: 0.2840 - val_acc: 0.9033
# Epoch 5/10
# 60000/60000 [==============================] - 127s 2ms/sample - loss: 0.1267 - acc: 0.9517 - val_loss: 0.2843 - val_acc: 0.9093
# Epoch 6/10
# 60000/60000 [==============================] - 124s 2ms/sample - loss: 0.1036 - acc: 0.9602 - val_loss: 0.3302 - val_acc: 0.9084
# Epoch 7/10
# 60000/60000 [==============================] - 127s 2ms/sample - loss: 0.0844 - acc: 0.9684 - val_loss: 0.3443 - val_acc: 0.9046
# Epoch 8/10
# 60000/60000 [==============================] - 127s 2ms/sample - loss: 0.0686 - acc: 0.9741 - val_loss: 0.3742 - val_acc: 0.9056
# Epoch 9/10
# 60000/60000 [==============================] - 125s 2ms/sample - loss: 0.0592 - acc: 0.9781 - val_loss: 0.4011 - val_acc: 0.9015
# Epoch 10/10
# 60000/60000 [==============================] - 128s 2ms/sample - loss: 0.0510 - acc: 0.9820 - val_loss: 0.4514 - val_acc: 0.8995

# %%
print("train score", model.evaluate(X_train,Y_train))
# Out:
# 60000/60000 [==============================] - 22s 374us/sample - loss: 0.0286 - acc: 0.9899
# train score [0.028582636373199057, 0.9899167]

# %%
print("test score", model.evaluate(X_test,Y_test))
# Out:
# 10000/10000 [==============================] - 4s 412us/sample - loss: 0.4514 - acc: 0.8995
# test score [0.45135888762027027, 0.8995]
